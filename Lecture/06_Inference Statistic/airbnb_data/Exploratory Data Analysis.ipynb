# %% [markdown]
# # Exploratory Data Analysis Example

# %% [markdown]
# ## The New York City (NYC) AirBnB Dataset

# %% [markdown]
# ![nyc_image.jpg](attachment:nyc_image.jpg)

# %% [markdown]
# ## Task

# %% [markdown]
# The ISDL Property Management LC plans to let some of their accommodations in New York City (NYC) via AirBnB. To find out what accommodations can generate the highest rent, they crawled the AirBnB data of NYC.
# As a junior data scientist, you have been asked to apply your new knowledge about exploratory data analysis and hypothesis testing to figure out what accommodations have the highest rent.

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all" #display all output not only the last


import numpy as np
import pandas as pd

nyc_data = pd.read_csv("data/AirBnB_Data_NYC.csv")
nyc_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           48895 non-null  int64
#  1   id                   48895 non-null  int64
#  2   name                 48879 non-null  object
#  3   host_id              48895 non-null  int64
#  4   host_name            48874 non-null  object
#  5   neighbourhood_group  48895 non-null  object
#  6   neighbourhood        48895 non-null  object
#  7   latitude             48895 non-null  float64
#  8   longitude            48895 non-null  float64
#  9   room_type            48895 non-null  object
#  10  price                48895 non-null  int64
#  11  minimum_nights       48895 non-null  int64
#  12  number_of_reviews    48895 non-null  int64
#  13  reviews_per_month    38843 non-null  float64
# dtypes: float64(3), int64(6), object(5)
# memory usage: 5.2+ MB

# %% [markdown]
# ## Data Overview

# %% [markdown]
# First, we look at the general structure of the dataset and the characteristics of the attributes.
#
# Number of attributes in the dataset: 13  <br>
# Number of observations in the dataset: 48895 <br>

# %%
nyc_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           48895 non-null  int64
#  1   id                   48895 non-null  int64
#  2   name                 48879 non-null  object
#  3   host_id              48895 non-null  int64
#  4   host_name            48874 non-null  object
#  5   neighbourhood_group  48895 non-null  object
#  6   neighbourhood        48895 non-null  object
#  7   latitude             48895 non-null  float64
#  8   longitude            48895 non-null  float64
#  9   room_type            48895 non-null  object
#  10  price                48895 non-null  int64
#  11  minimum_nights       48895 non-null  int64
#  12  number_of_reviews    48895 non-null  int64
#  13  reviews_per_month    38843 non-null  float64
# dtypes: float64(3), int64(6), object(5)
# memory usage: 5.2+ MB

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# Before analyzing the data, we need to prepare the data for further processing. It is a good practice to check for missing values or invalid values in the dataset.

# %% [markdown]
# #### Screen all olumns for NaN or missing values

# %%
nyc_data.isnull().sum()
# Out:
# Unnamed: 0                 0
# id                         0
# name                      16
# host_id                    0
# host_name                 21
# neighbourhood_group        0
# neighbourhood              0
# latitude                   0
# longitude                  0
# room_type                  0
# price                      0
# minimum_nights             0
# number_of_reviews          0
# reviews_per_month      10052
# dtype: int64

# %% [markdown]
# Let's first look at reviews_per_month which contain the most missing values <br>
# Let's analyze whether reviews_per_month is always missing if number of reviews is 0.

# %%
data1 = nyc_data['number_of_reviews']==0

# %%
data2 = nyc_data['reviews_per_month'].isnull()

# %%
data1.equals(data2)
# Out:
# True

# %% [markdown]
# The data seems valid.

# %% [markdown]
# #### Search for empty strings

# %% [markdown]
# Lets consider the column 'name'

# %%
nyc_data["name"].isnull().sum()
#Show the data where 'name' is null
nyc_data[nyc_data["name"].isnull()]
# Out:
# 16
#        Unnamed: 0        id name   host_id host_name neighbourhood_group  \
# 2854         2854   1615764  NaN   6676776     Peter           Manhattan
# 3703         3703   2232600  NaN  11395220      Anna           Manhattan
# 5775         5775   4209595  NaN  20700823     Jesse           Manhattan
# 5975         5975   4370230  NaN  22686810   Michaël           Manhattan
# 6269         6269   4581788  NaN  21600904     Lucie            Brooklyn
# 6567         6567   4756856  NaN   1832442  Carolina            Brooklyn
# 6605         6605   4774658  NaN  24625694      Josh           Manhattan
# 8841         8841   6782407  NaN  31147528  Huei-Yin            Brooklyn
# 11963       11963   9325951  NaN  33377685  Jonathan           Manhattan
# 12824       12824   9787590  NaN  50448556    Miguel           Manhattan
# 13059       13059   9885866  NaN  37306329  Juliette           Manhattan
# 13401       13401  10052289  NaN  49522403   Vanessa            Brooklyn
# 15819       15819  12797684  NaN  69715276       Yan           Manhattan
# 16071       16071  12988898  NaN  71552588    Andrea               Bronx
# 18047       18047  14135050  NaN  85288337      Jeff            Brooklyn
# 28889       28889  22275821  NaN  49662398  Kathleen            Brooklyn
#
#             neighbourhood  latitude  longitude        room_type  price  \
# 2854    Battery Park City  40.71239  -74.01620  Entire home/apt    400
# 3703         East Village  40.73215  -73.98821  Entire home/apt    200
# 5775    Greenwich Village  40.73473  -73.99244  Entire home/apt    225
# 5975               Nolita  40.72046  -73.99550  Entire home/apt    215
# 6269         Williamsburg  40.71370  -73.94378     Private room    150
# 6567             Bushwick  40.70046  -73.92825     Private room     70
# 6605   Washington Heights  40.85198  -73.93108     Private room     40
# 8841         Williamsburg  40.71354  -73.93882     Private room     45
# 11963      Hell's Kitchen  40.76436  -73.98573  Entire home/apt    190
# 12824              Harlem  40.80316  -73.95189  Entire home/apt    300
# 13059           Chinatown  40.71632  -73.99328     Private room     67
# 13401         Brownsville  40.66409  -73.92314     Private room     50
# 15819     Upper West Side  40.79843  -73.96404     Private room    100
# 16071             Fordham  40.86032  -73.88493      Shared room    130
# 18047  Bedford-Stuyvesant  40.69421  -73.93234     Private room     70
# 28889            Bushwick  40.69546  -73.92741  Entire home/apt    110
#
#        minimum_nights  number_of_reviews  reviews_per_month
# 2854             1000                  0                NaN
# 3703                1                 28               0.45
# 5775                1                  1               0.02
# 5975                7                  5               0.09
# 6269                1                  0                NaN
# 6567                1                  0                NaN
# 6605                1                  0                NaN
# 8841                1                  0                NaN
# 11963               4                  1               0.02
# 12824               5                  0                NaN
# 13059               4                  0                NaN
# 13401               3                  3               0.07
# 15819               1                  0                NaN
# 16071               1                  0                NaN
# 18047               3                  0                NaN
# 28889               4                  5               0.27

# %% [markdown]
# There are 16 observations without a name. This seems strange, as accommodations normally have names, thus we delete this data

# %%
# Delete all observations where the name is empty

# Get the index of all rows that should be deleted
emptyNameIndexes = nyc_data[nyc_data.name.isnull()].index

nyc_data.drop(emptyNameIndexes, inplace=True)

# Check whether data is delete
nyc_data["name"].isnull().sum()
# Out:
# 0

# %% [markdown]
# Lets consider the column 'host_name'

# %%
# Search for empty strings in hostname
nyc_data["host_name"].isnull().sum()
nyc_data[nyc_data["host_name"].isnull()]
# Out:
# 21
#        Unnamed: 0        id  \
# 360           360    100184
# 2700         2700   1449546
# 5745         5745   4183989
# 6075         6075   4446862
# 6582         6582   4763327
# 8163         8163   6292866
# 8257         8257   6360224
# 8852         8852   6786181
# 9138         9138   6992973
# 9817         9817   7556587
# 14040       14040  10709846
# 14631       14631  11553543
# 15174       15174  12113879
# 19565       19565  15648096
# 27777       27777  21787094
# 27962       27962  21867710
# 28042       28042  21901156
# 28274       28274  21990808
# 30570       30570  23660605
# 32193       32193  25180572
# 38992       38992  30468335
#
#                                                     name    host_id host_name  \
# 360                                            Bienvenue     526653       NaN
# 2700                             Cozy Studio in Flatbush    7779204       NaN
# 5745     SPRING in the City!! Zen-Style Tranquil Bedroom     919218       NaN
# 6075                  Charming Room in Prospect Heights!   23077718       NaN
# 6582                 Luxurious, best location, spa inc'l   24576978       NaN
# 8163                           Modern Quiet Gem Near All   32722063       NaN
# 8257                     Sunny, Private room in Bushwick   33134899       NaN
# 8852                        R&S Modern Spacious Hideaway   32722063       NaN
# 9138                     1 Bedroom in Prime Williamsburg    5162530       NaN
# 9817                                Sunny Room in Harlem   39608626       NaN
# 14040                 Sunny, spacious room in Greenpoint    7822683       NaN
# 14631                                  Cozy Room Astoria   26138712       NaN
# 15174     Sunny, Large West Village 1 BR Near Everything    5300585       NaN
# 19565              Spacious 2 bedroom close to Manhattan  100971588       NaN
# 27777         Spacious and Bright Midtown East Apartment     415290       NaN
# 27962  Amazing room in the centre on Manhatten! Welcome!  159156636       NaN
# 28042  Best Deal! Lovely place in Manhattan! Time Squ...  159156636       NaN
# 28274                 ***SLEEPING IN THE GOLDEN PLACE***  159156636       NaN
# 30570    Private Bedroom w/ Balcony view of Central Park  177146433       NaN
# 32193                     Beautiful Cozy Studio Apt. UWS  119609345       NaN
# 38992            LARGE Prospect Lefferts Gardens Bedroom  228750026       NaN
#
#       neighbourhood_group     neighbourhood  latitude  longitude  \
# 360                Queens    Queens Village  40.72413  -73.76133
# 2700             Brooklyn          Flatbush  40.64965  -73.96154
# 5745            Manhattan            Harlem  40.80606  -73.95061
# 6075             Brooklyn     Crown Heights  40.67512  -73.96146
# 6582             Brooklyn        Greenpoint  40.72035  -73.95355
# 8163             Brooklyn     East Flatbush  40.65263  -73.93215
# 8257             Brooklyn          Bushwick  40.70146  -73.92792
# 8852             Brooklyn     East Flatbush  40.64345  -73.93643
# 9138             Brooklyn      Williamsburg  40.71838  -73.95630
# 9817            Manhattan            Harlem  40.82929  -73.94182
# 14040            Brooklyn        Greenpoint  40.73539  -73.95838
# 14631              Queens  Ditmars Steinway  40.77587  -73.91775
# 15174           Manhattan           Chelsea  40.73949  -73.99801
# 19565               Bronx        Highbridge  40.83844  -73.92489
# 27777           Manhattan   Upper East Side  40.76436  -73.96836
# 27962           Manhattan    Hell's Kitchen  40.75668  -73.99097
# 28042           Manhattan    Hell's Kitchen  40.75656  -73.99063
# 28274           Manhattan    Hell's Kitchen  40.75835  -73.99065
# 30570           Manhattan       East Harlem  40.79766  -73.94824
# 32193           Manhattan   Upper West Side  40.77701  -73.97667
# 38992            Brooklyn          Flatbush  40.65152  -73.95271
#
#              room_type  price  minimum_nights  number_of_reviews  \
# 360       Private room     50               1                 43
# 2700   Entire home/apt    100              30                 49
# 5745      Private room     86               3                 34
# 6075      Private room     50               1                  0
# 6582   Entire home/apt    195               1                  1
# 8163   Entire home/apt     85               2                182
# 8257      Private room     37               1                  1
# 8852   Entire home/apt    100               2                157
# 9138   Entire home/apt    145               1                  0
# 9817      Private room     28               1                  1
# 14040     Private room     55              10                  2
# 14631     Private room     45               1                  5
# 15174  Entire home/apt    220               4                 81
# 19565  Entire home/apt     75               4                 37
# 27777  Entire home/apt    325               1                  0
# 27962     Private room    120               1                 89
# 28042     Private room    120               1                109
# 28274     Private room    120               1                 88
# 30570     Private room    139               1                  6
# 32193  Entire home/apt    180               4                  0
# 38992     Private room     55               7                  0
#
#        reviews_per_month
# 360                 0.45
# 2700                0.69
# 5745                1.00
# 6075                 NaN
# 6582                0.02
# 8163                3.59
# 8257                0.02
# 8852                3.18
# 9138                 NaN
# 9817                0.02
# 14040               0.05
# 14631               0.13
# 15174               2.11
# 19565               1.21
# 27777                NaN
# 27962               5.16
# 28042               5.97
# 28274               4.93
# 30570               0.46
# 32193                NaN
# 38992                NaN

# %% [markdown]
# There are 21 observations with empty strings. This seems strange, because every host should have a name, thus we delete these observations.

# %%
# Get the index of all rows that should be deleted
emtyHostNameIndex = nyc_data[nyc_data.host_name.isnull()].index

# Delete data
nyc_data.drop(emtyHostNameIndex, inplace=True)

# Check whether data is delete
nyc_data["host_name"].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Check for unrealistic prices
#
# Check whether there are accommodations which are listed with a price of 0$

# %%
nyc_data.loc[nyc_data["price"]==0,"price"].count()
# Out:
# 11

# %% [markdown]
# There are 11 observations where the price is $0. This appears suspect, because nobody gives away the accommodation for free, thus we remove the observations.

# %%
#Get index of the observations with price equal 0
priceZeroIndex = nyc_data[nyc_data["price"] ==0].index
# Delete data
nyc_data.drop(priceZeroIndex, inplace=True)

# Check whether data is delete
nyc_data.loc[nyc_data["price"]==0,"price"].count()
# Out:
# 0

# %% [markdown]
# Check for unrealistically high prices

# %%
nyc_data["price"].mean()
nyc_data.price.median()

nyc_data.nlargest(50,"price")
# Out:
# 152.77470469015498
# 106.0
#        Unnamed: 0        id  \
# 9151         9151   7003697
# 17692       17692  13894339
# 29238       29238  22436899
# 6530         6530   4737930
# 12342       12342   9528920
# 40433       40433  31340283
# 30268       30268  23377410
# 4377         4377   2953058
# 29662       29662  22779726
# 42523       42523  33007610
# 45666       45666  34895693
# 44034       44034  33998396
# 3774         3774   2271504
# 37194       37194  29547314
# 48043       48043  36056808
# 29664       29664  22780103
# 3537         3537   2110145
# 15560       15560  12520066
# 3720         3720   2243699
# 43009       43009  33397385
# 2698         2698   1448703
# 4345         4345   2919330
# 22353       22353  18051877
# 25825       25825  20654227
# 26739       26739  21238053
# 38000       38000  30035166
# 4376         4376   2952861
# 46614       46614  35345358
# 43670       43670  33796251
# 45867       45867  34981637
# 28947       28947  22296197
# 42736       42736  33171891
# 1862         1862    826690
# 3695         3695   2224896
# 21821       21821  17537893
# 25901       25901  20692563
# 17665       17665  13882394
# 3788         3788   2281142
# 34851       34851  27629043
# 42542       42542  33029434
# 37864       37864  29964348
# 29663       29663  22779746
# 41216       41216  32054910
# 28946       28946  22296097
# 39243       39243  30589636
# 946           946    363673
# 18632       18632  14730708
# 28727       28727  22207357
# 28858       28858  22263855
# 38223       38223  30146411
#
#                                                     name    host_id  \
# 9151                 Furnished room in Astoria apartment   20582832
# 17692    Luxury 1 bedroom apt. -stunning Manhattan views    5143901
# 29238                                1-BR Lincoln Center   72390391
# 6530                                  Spanish Harlem Apt    1235070
# 12342                Quiet, Clean, Lit @ LES & Chinatown    3906464
# 40433  2br - The Heart of NYC: Manhattans Lower East ...    4382127
# 30268  Beautiful/Spacious 1 bed luxury flat-TriBeCa/Soho   18128455
# 4377                                       Film Location    1177497
# 29662          East 72nd Townhouse by (Hidden by Airbnb)  156158778
# 42523                70' Luxury MotorYacht on the Hudson    7407743
# 45666                               Gem of east Flatbush  262534951
# 44034                   3000 sq ft daylight photo studio    3750764
# 3774                    SUPER BOWL Brooklyn Duplex Apt!!   11598359
# 37194             Apartment New York \r\nHell’s Kitchens   35303743
# 48043       Luxury TriBeCa Apartment at an amazing price  271248669
# 29664          Park Avenue Mansion by (Hidden by Airbnb)  156158778
# 3537                  UWS 1BR w/backyard + block from CP    2151325
# 15560                 Luxury townhouse Greenwich Village   66240032
# 3720                 SuperBowl Penthouse Loft 3,000 sqft    1483320
# 43009    Midtown Manhattan great location (Gramacy park)   16105313
# 2698                 Beautiful 1 Bedroom in Nolita/Soho      213266
# 4345                    NearWilliamsburg bridge 11211 BK   14908606
# 22353                            Victorian Film location    2675644
# 25825                                           Fulton 2  100069033
# 26739                                         Broadway 1  153497815
# 38000      4-Floor Unique Event Space 50P Cap. - #10299B  172611460
# 4376                                Photography Location    1177497
# 46614                     Northside Williamsburg Stunner     956324
# 43670   Beautiful private Brooklyn room with kitchenette    8748976
# 45867        bay ridge & sunset park furnished apartment  263564234
# 28947   Chelsea Gallery for events, exhibitions, fashion    3750764
# 42736  30 days minimum Time square West Midtown apart...  177396569
# 1862                    Sunny, Family-Friendly 2 Bedroom    4289240
# 3695                 NYC SuperBowl Wk 5 Bdrs River View    11353904
# 21821  The Otheroom Bar/Event/Filming Space -read det...   18037301
# 25901    Greenwich Village Townhome with Private Garden!  147814925
# 17665        VIP Duplex Townhouse with Private Garden!!!   49186997
# 3788                  Prime NYC Location for Super Bowl     1427243
# 34851             A Night at Anchor Aboard Yacht Ventura   45863742
# 42542             West 84th Street by (Hidden by Airbnb)  156158778
# 37864                 NYC HOLIDAY!!!!   April 15- May 15    2039658
# 29663          East 7th Street III by (Hidden by Airbnb)  156158778
# 41216             West 88th Street by (Hidden by Airbnb)  156158778
# 28946   Chelsea Gallery Space for events and exhibitions    3750764
# 39243     Furnished 1000sq large 2bed + office in Harlem  229458601
# 946                     Beautiful 3 bedroom in Manhattan     256239
# 18632  Breathtaking City Views 3 Bed Apt. in Lincoln Sq!     836168
# 28727                                      The room boom  162116640
# 28858       SPECTACULAR SOHO GREAT ROOM LOFT 6000sq feet    6145729
# 38223    Luxury West Village private Townhouse 5B Garden  101080203
#
#              host_name neighbourhood_group       neighbourhood  latitude  \
# 9151          Kathrine              Queens             Astoria  40.76810
# 17692             Erin            Brooklyn          Greenpoint  40.73260
# 29238           Jelena           Manhattan     Upper West Side  40.77213
# 6530             Olson           Manhattan         East Harlem  40.79264
# 12342              Amy           Manhattan     Lower East Side  40.71355
# 40433             Matt           Manhattan     Lower East Side  40.71980
# 30268              Rum           Manhattan             Tribeca  40.72197
# 4377           Jessica            Brooklyn        Clinton Hill  40.69137
# 29662            Sally           Manhattan     Upper East Side  40.76824
# 42523             Jack           Manhattan   Battery Park City  40.71162
# 45666           Sandra            Brooklyn       East Flatbush  40.65724
# 44034            Kevin           Manhattan             Chelsea  40.75060
# 3774          Jonathan            Brooklyn        Clinton Hill  40.68766
# 37194         Patricia           Manhattan     Upper West Side  40.76835
# 48043            Jenny           Manhattan             Tribeca  40.71206
# 29664            Sally           Manhattan     Upper East Side  40.78517
# 3537       Jay And Liz           Manhattan     Upper West Side  40.77782
# 15560            Linda           Manhattan   Greenwich Village  40.73046
# 3720              Omri           Manhattan        Little Italy  40.71895
# 43009            Debra           Manhattan             Midtown  40.74482
# 2698           Jessica           Manhattan              Nolita  40.72193
# 4345            Bianca            Brooklyn  Bedford-Stuyvesant  40.69572
# 22353           Alissa       Staten Island       Randall Manor  40.63952
# 25825          Sarah-2            Brooklyn       Cypress Hills  40.68185
# 26739          Sarah-B            Brooklyn  Bedford-Stuyvesant  40.68742
# 38000           Rasmus           Manhattan              Harlem  40.82511
# 4376           Jessica            Brooklyn        Clinton Hill  40.69127
# 46614             Alex            Brooklyn        Williamsburg  40.71705
# 43670          Jeffrey            Brooklyn  Bedford-Stuyvesant  40.68807
# 45867             Nony            Brooklyn           Bay Ridge  40.63087
# 28947            Kevin           Manhattan             Chelsea  40.74888
# 42736           Yanina           Manhattan      Hell's Kitchen  40.76043
# 1862              Lucy            Brooklyn    Prospect Heights  40.67919
# 3695              Todd           Manhattan     Upper West Side  40.79476
# 21821            James           Manhattan        West Village  40.73571
# 25901            Lloyd           Manhattan   Greenwich Village  40.73300
# 17665           Joseph           Manhattan   Greenwich Village  40.73305
# 3788           Jordana           Manhattan        East Village  40.73323
# 34851            James           Manhattan   Battery Park City  40.71364
# 42542            Sally           Manhattan     Upper West Side  40.78545
# 37864              Pam           Manhattan     Upper East Side  40.76519
# 29663            Sally           Manhattan        East Village  40.72779
# 41216            Sally           Manhattan     Upper West Side  40.78742
# 28946            Kevin           Manhattan             Chelsea  40.74913
# 39243              Kay           Manhattan              Harlem  40.81315
# 946             Tracey           Manhattan     Upper West Side  40.80142
# 18632            Henry           Manhattan     Upper West Side  40.77910
# 28727            Tuvia            Brooklyn      Brighton Beach  40.58363
# 28858        Stephanie           Manhattan                SoHo  40.72605
# 38223  Luxury Property           Manhattan            Gramercy  40.73652
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 9151   -73.91651     Private room  10000             100                  2
# 17692  -73.95739  Entire home/apt  10000               5                  5
# 29238  -73.98665  Entire home/apt  10000              30                  0
# 6530   -73.93898  Entire home/apt   9999               5                  1
# 12342  -73.98507     Private room   9999              99                  6
# 40433  -73.98566  Entire home/apt   9999              30                  0
# 30268  -74.00633  Entire home/apt   8500              30                  2
# 4377   -73.96723  Entire home/apt   8000               1                  1
# 29662  -73.95989  Entire home/apt   7703               1                  0
# 42523  -74.01693  Entire home/apt   7500               1                  0
# 45666  -73.92450     Private room   7500               1                  8
# 44034  -74.00388  Entire home/apt   6800               1                  0
# 3774   -73.96439  Entire home/apt   6500               1                  0
# 37194  -73.98367     Private room   6500              30                  0
# 48043  -74.00999  Entire home/apt   6500             180                  0
# 29664  -73.95270  Entire home/apt   6419               1                  0
# 3537   -73.97848  Entire home/apt   6000              14                 17
# 15560  -73.99562  Entire home/apt   6000               1                  0
# 3720   -73.99793  Entire home/apt   5250               1                  0
# 43009  -73.98367  Entire home/apt   5100              30                  1
# 2698   -73.99379  Entire home/apt   5000               1                  2
# 4345   -73.95731     Private room   5000               6                 10
# 22353  -74.09730  Entire home/apt   5000               1                  0
# 25825  -73.88128  Entire home/apt   5000               2                  4
# 26739  -73.91957  Entire home/apt   5000               2                  8
# 38000  -73.94961  Entire home/apt   5000               1                  2
# 4376   -73.96563  Entire home/apt   4500               1                  5
# 46614  -73.96470  Entire home/apt   4500              30                  0
# 43670  -73.95426     Private room   4200             114                  0
# 45867  -74.02006  Entire home/apt   4200              60                  0
# 28947  -74.00481  Entire home/apt   4160               1                  0
# 42736  -73.99132  Entire home/apt   4100              30                  0
# 1862   -73.97191  Entire home/apt   4000               4                  0
# 3695   -73.97299  Entire home/apt   4000               1                  0
# 21821  -74.00780  Entire home/apt   4000               1                  0
# 25901  -73.99413  Entire home/apt   3900              30                  7
# 17665  -73.99373  Entire home/apt   3800              30                  2
# 3788   -73.98859  Entire home/apt   3750               1                  0
# 34851  -74.01758  Entire home/apt   3750               1                  0
# 42542  -73.97123  Entire home/apt   3613               1                  1
# 37864  -73.96874  Entire home/apt   3600              31                  0
# 29663  -73.98644  Entire home/apt   3518               1                  0
# 41216  -73.97011  Entire home/apt   3512               1                  0
# 28946  -74.00373     Private room   3210               1                  0
# 39243  -73.95110  Entire home/apt   3200              90                  0
# 946    -73.96931     Private room   3000               7                  0
# 18632  -73.98182  Entire home/apt   3000              30                  8
# 28727  -73.96405     Private room   3000               1                  0
# 28858  -74.00572  Entire home/apt   3000               7                  1
# 38223  -73.98618  Entire home/apt   3000               1                  1
#
#        reviews_per_month
# 9151                0.04
# 17692               0.16
# 29238                NaN
# 6530                0.02
# 12342               0.14
# 40433                NaN
# 30268               0.18
# 4377                0.03
# 29662                NaN
# 42523                NaN
# 45666               6.15
# 44034                NaN
# 3774                 NaN
# 37194                NaN
# 48043                NaN
# 29664                NaN
# 3537                0.27
# 15560                NaN
# 3720                 NaN
# 43009               1.00
# 2698                0.03
# 4345                0.16
# 22353                NaN
# 25825               0.18
# 26739               0.38
# 38000               0.38
# 4376                0.09
# 46614                NaN
# 43670                NaN
# 45867                NaN
# 28947                NaN
# 42736                NaN
# 1862                 NaN
# 3695                 NaN
# 21821                NaN
# 25901               0.32
# 17665               0.06
# 3788                 NaN
# 34851                NaN
# 42542               1.00
# 37864                NaN
# 29663                NaN
# 41216                NaN
# 28946                NaN
# 39243                NaN
# 946                  NaN
# 18632               0.24
# 28727                NaN
# 28858               1.00
# 38223               0.15

# %% [markdown]
# There are various appartments that appear to have unrealistic prices.
# A quick search in AirBnB shows that prices above 4500 dollar rarely exist or not to be taken seriously.
# To increase the quality of our data set, we delete all accomondations with prices above 4500 dollar.

# %%
#Get index of the observations with outlier prices
priceOutlierIndex = nyc_data[nyc_data["price"] > 4500].index
# Delete data
nyc_dataCleaned = nyc_data.drop(priceOutlierIndex)

nyc_dataCleaned.loc[nyc_dataCleaned["price"] > 4500, "price"].count()
# Out:
# 0

# %% [markdown]
# ## Visualization of the data

# %% [markdown]
# Let’s visualize the distribution of the accommodations among the five neighbourhood groups.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# convert neighbourhood_group to categorical to ensure it is displayed alphabetically
nyc_dataCleaned['neighbourhood_group'] = pd.Categorical(nyc_dataCleaned['neighbourhood_group'], ["Bronx", "Brooklyn","Manhattan","Queens","Staten Island"])

plt.figure(figsize=(6,3), dpi = 150)
ax = sns.histplot(data=nyc_dataCleaned, x="neighbourhood_group",  hue = "neighbourhood_group", legend = False)
ax.set_title("Distribution of accommodations among neighbourhood groups")
ax.set_xlabel("neighbourhood group")
ax.set_ylabel("Number of accommodations")
# Out:
# Text(0.5, 1.0, 'Distribution of accommodations among neighbourhood groups')
# Text(0.5, 0, 'neighbourhood group')
# Text(0, 0.5, 'Number of accommodations')

# %% [markdown]
# Brooklyn and Manhattan have the most accommodations.

# %% [markdown]
# #### Let’s visualize the price of the accommodations for each neighbourhood group

# %%
plt.figure(figsize=(6,3), dpi = 300)

ax2 = sns.boxplot(data=nyc_dataCleaned, x="neighbourhood_group", y= "price", hue = "neighbourhood_group", dodge=False)
ax2.set_title("Distribution of price among different neighbourhood groups")
ax2.set_xlabel("neighbourhood group")
plt.legend(loc='center right', bbox_to_anchor=(1.5, 0.5), ncol=1)
# Out:
# Text(0.5, 1.0, 'Distribution of price among different neighbourhood groups')
# Text(0.5, 0, 'neighbourhood group')

# %%
plt.figure(figsize=(6,3), dpi = 300)

ax2 = sns.boxplot(data=nyc_dataCleaned, x="neighbourhood_group", y= "price", hue = "neighbourhood_group", dodge=False)
ax2.set(ylim=(0,500)) # zoom in to get better understanding of the data
ax2.set_title("Distribution of price among different neighbourhood groups")
ax2.set_xlabel("neighbourhood group")
plt.legend(loc='center right', bbox_to_anchor=(1.5, 0.5), ncol=1)
# Out:
# [(0.0, 500.0)]
# Text(0.5, 1.0, 'Distribution of price among different neighbourhood groups')
# Text(0.5, 0, 'neighbourhood group')

# %% [markdown]
# We see that the prices are quite different for each neighborhood group. Manhattan seems to be the most expensive. <br>
# We can visualize the distribution of the prices on a map, by using the longitude and latitude data.

# %% [markdown]
# #### Display the neighbourhood groups

# %%
plt.figure(figsize=(6,5), dpi = 300)
ax3 = sns.scatterplot(data=nyc_dataCleaned, x="longitude", y= "latitude", hue = "neighbourhood_group")
ax3.set_title("Neighbourhood groups in NYC")
ax3.set_xlabel("longitude")
ax3.set_ylabel("latitude")
plt.legend(loc='center right', bbox_to_anchor=(1.5, 0.5), ncol=1)
# Out:
# Text(0.5, 1.0, 'Neighbourhood groups in NYC')
# Text(0.5, 0, 'longitude')
# Text(0, 0.5, 'latitude')

# %% [markdown]
# #### Display the prices of the accommodations

# %%
# For a better readability: we set the price above median price to the median price
import statistics
median_price = statistics.median(nyc_dataCleaned['price'])
median_price

def f(row):
    if row["price"] > median_price:
        val = median_price
    else:
        val = row["price"]
    return val

nyc_dataCleaned['price_capped'] = nyc_data.apply(f, axis=1)
# Out:
# 106

# %%
plt.figure(figsize=(6,5), dpi = 300)
ax4 = sns.scatterplot(data=nyc_dataCleaned, x="longitude", y= "latitude", hue = "price_capped", palette="coolwarm", alpha=0.05)
ax4.set_title("Neighbourhood groups in NYC")
ax4.set_xlabel("longitude")
ax4.set_ylabel("latitude")
plt.legend(loc='center right', bbox_to_anchor=(1.5, 0.5), ncol=1)
# Out:
# Text(0.5, 1.0, 'Neighbourhood groups in NYC')
# Text(0.5, 0, 'longitude')
# Text(0, 0.5, 'latitude')

# %% [markdown]
# This also shows that Manhattan has the most accommodations with a price above the median (red dots)

# %% [markdown]
# ## Hypothesis testing (t-test)

# %% [markdown]
# The exploratory data analysis suggests that Manhattan might be the most neighbourhood group with the highest prices. Let’s try to back this claim up with some statistics.

# %% [markdown]
# Mean, median and standard deviation of the price for each neighbourhood group

# %%
nyc_dataCleaned.groupby("neighbourhood_group").price.mean()
# Out:
# neighbourhood_group
# Bronx             87.549632
# Brooklyn         122.168236
# Manhattan        191.407306
# Queens            97.787745
# Staten Island    101.680108
# Name: price, dtype: float64

# %%
nyc_dataCleaned.groupby("neighbourhood_group").price.median()
# Out:
# neighbourhood_group
# Bronx             65.0
# Brooklyn          90.0
# Manhattan        150.0
# Queens            75.0
# Staten Island     75.0
# Name: price, dtype: float64

# %%
nyc_dataCleaned.groupby("neighbourhood_group").price.std()
# Out:
# neighbourhood_group
# Bronx            106.815075
# Brooklyn         136.835601
# Manhattan        209.639598
# Queens           103.063813
# Staten Island    113.055778
# Name: price, dtype: float64

# %% [markdown]
# Manhattan has the highest mean and median price, however, the standard deviation is very high. The numbers indicate that Manhattan might be the neighbourhood group with the highest price.
# We next test whether this happens at random or if there is a statistically significant difference in the prices.

# %% [markdown]
# Let’s analyze whether the prices for accomondatons in Manhattan are statistically higher than in the rest of New York City.

# %% [markdown]
# #### Preconditions for t-test
#
# ##### 1. Normal distribution
# We can assume that the data is normally distributed, because of the large data set.
#
# ##### 2. Homogeneity of variance
#
# Before we do the t-test, we need to check for homogeneity of variance, because this determines whether to use the t-test or the Welch-test.

# %% [markdown]
# Levene-Test for homogeneity of variance across groups
# - H0 for Levene-Test: There is homogeneity of variance for both groups ("both groups have similar variance")
# - H1 for Levene-Test: There is no homogeneity of variance for both groups ("both groups have different variance")

# %%
from scipy.stats import levene

manhattan = nyc_dataCleaned.loc[nyc_dataCleaned["neighbourhood_group"] == "Manhattan",:]
notManhattan = nyc_dataCleaned.loc[nyc_dataCleaned["neighbourhood_group"] != "Manhattan",:]

stat, p = levene(manhattan.price, notManhattan.price, center="median")
stat, p
# Out:
# (797.2205092652749, 5.472370211142615e-174)

# %% [markdown]
# We reject H0 because the the Levene-Test shows that there is no variance homogeneity: F(1,48821) = 797.22, p < 0.001. <br>
# Therefore, we use the Welch test (t-test for variance inhomogeneity), instead of the normal t-test.

# %% [markdown]
# #### Create dataset for the independent t-test
# Create dataset the independent t-test: One with accommodations from Manhattan and one data set with the rest

# %%
manhattan = nyc_dataCleaned.loc[nyc_dataCleaned["neighbourhood_group"] == "Manhattan",:]
notManhattan = nyc_dataCleaned.loc[nyc_dataCleaned["neighbourhood_group"] != "Manhattan",:]

# %% [markdown]
# #### T-test (for variance inhomogeneity)

# %% [markdown]
# H0: The price of accommodations in Manhattan equal to the price of accommodations in the rest of New York City <br>
# H1: The price of accommodations in Manhattan greater than the price of accommodations in the rest of New York City

# %%
from scipy.stats import ttest_ind
ttest_ind(manhattan.price, notManhattan.price, equal_var=False, alternative = "greater")
# Out:
# Ttest_indResult(statistic=46.67635074535276, pvalue=0.0)

# %%
manhattan.price.mean()
# Out:
# 191.4073063583815

# %%
notManhattan.price.mean()
# Out:
# 115.4263126930431

# %% [markdown]
# We reject the Null Hypotheses (H0) and accept the alternative hypotheses (H1)<br>
# <br>
# Interpretation: <br>
# This analysis shows that accommodations in Manhattan are statistically significantly more expensive (mean: 191.41) compared to accommodations in the rest of New York City (115.43).<br>
# t=46.67, p < 0.001.

# %% [markdown]
# ## Hypothesis testing (ANOVA)

# %% [markdown]
# Let’s further analyze whether there are differences in the Manhattan accomondatoins when also considering the room type of the accommodation.

# %%
# convert room_type to categorical to ensure that the graph is ordered alphabetically
nyc_dataCleaned['room_type'] = pd.Categorical(nyc_dataCleaned['room_type'], ["Private room", "Entire home/apt", "Shared room"])

# create new dataset containing only manhattan but all other attributes
manhattan_data = nyc_dataCleaned.loc[nyc_data["neighbourhood_group"]=="Manhattan",:]

# %%
plt.figure(figsize=(6,3), dpi = 150)
ax2 = sns.boxplot(data=manhattan_data, x="room_type", y= "price", dodge=False)
ax2.set_yscale('log') # # We use the log of the price, because the range is too large. Otherwise, the boxplot is hard to read
ax2.set_title("Distribution of price among different room types in Manhattan")
ax2.set_xlabel("room type")
ax2.set_ylabel("price")
# Out:
# Text(0.5, 1.0, 'Distribution of price among different room types in Manhattan')
# Text(0.5, 0, 'room type')
# Text(0, 0.5, 'price')

# %%
manhattan_data.groupby("room_type").price.mean()
# Out:
# room_type
# Private room       114.765023
# Entire home/apt    241.512221
# Shared room         88.977083
# Name: price, dtype: float64

# %%
manhattan_data.groupby("room_type").price.median()
# Out:
# room_type
# Private room        90.0
# Entire home/apt    190.0
# Shared room         69.0
# Name: price, dtype: float64

# %%
manhattan_data.groupby("room_type").price.std()
# Out:
# room_type
# Private room       137.298033
# Entire home/apt    232.337021
# Shared room         92.416534
# Name: price, dtype: float64

# %% [markdown]
# It seems like the type “entire home/apt” is the most expensive room type. But it is unclear whether the differences are actually significant. <br>
# Let’s try to determine whether there are any statistically significant differences between the prices of the three room-types. We use a one-way ANOVA for this.

# %% [markdown]
# #### Preconditions for ANOVA
#
# ##### 1. Normal distribution
# We can assume that the data is normally distributed, because of the large data set.
#
# ##### 2. Homogeneity of variance
#  Before we do the ANOVA, we need to check for homogeneity of variance, because it determines whether to use the ANOVA or Welch's F-Test.
#
# Levene-Test for homogeneity of variance across groups
# - H0 for Levene-Test: There is homogeneity of variance for all three groups
# - H1 for Levene-Test: There is no homogeneity of variance for all three groups

# %%
manhatten_data_PrivateRoom = manhattan_data.loc[manhattan_data["room_type"]== "Private room",:]
manhatten_data_EntireHome = manhattan_data.loc[manhattan_data["room_type"]== "Entire home/apt",:]
manhatten_data_SharedRoom = manhattan_data.loc[manhattan_data["room_type"]== "Shared room",:]

# %%
from scipy.stats import levene
stat, p = levene(manhatten_data_PrivateRoom.price,manhatten_data_EntireHome.price, manhatten_data_SharedRoom.price, center="median")
stat, p
# Out:
# (222.21402387811895, 2.9655656306438667e-96)

# %% [markdown]
# We reject H0 because the the Levene-Test shows that there is no variance homogeneity: F = 222.21, p < 0.0. Therefore, we use the Welch’s F-Test.

# %% [markdown]
# #### Welch's F-Test

# %% [markdown]
# - H0: The mean price is equal for all three room types. <br>
# - H1: There is a significant difference in the mean price for all three room types.

# %%
from statsmodels.stats.oneway import anova_oneway
anova_oneway(manhattan_data.price, manhattan_nyc_data.room_type, use_var = "unequal")
# Out:
# <class 'statsmodels.stats.base.HolderTuple'>
# statistic = 1377.3030388174616
# pvalue = 0.0
# df = (2.0, 1456.616118372172)
# df_num = 2.0
# df_denom = 1456.616118372172
# nobs_t = 21625.0
# n_groups = 3
# means = [241.51222104 114.76502321  88.97708333]
# nobs = [13174.  7971.   480.]
# vars_ = [53980.49127248 18850.74992327  8540.81575765]
# use_var = unequal
# welch_correction = True
# tuple = (1377.3030388174616, 0.0)

# %% [markdown]
# There was a statistically significant difference between groups as determined by the Welch-F-Test (F = 1377.30, p < 0.001). <br>
# We reject H0 and accept H1. <br>
# <br>
# Interpretation: <br>
# We can see that the significance value is below 0.05 and, therefore, there is a statistically significant difference in the mean price per night between the different room types. <br>
# This is great to know, but we do not know which of the specific room types differed. We can find this out with a TukeyHSD post hoc test.

# %% [markdown]
# #### ANOVA TukeyHSD Post Hoc test

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
tukey = pairwise_tukeyhsd(endog=manhattan_data["price"], groups=manhattan_data["room_type"], alpha = 0.01)
print(tukey)
# Out:
#           Multiple Comparison of Means - Tukey HSD, FWER=0.01
# ========================================================================
#      group1        group2     meandiff p-adj    lower     upper   reject
# ------------------------------------------------------------------------
# Entire home/apt Private room -126.7472  0.001 -135.0195 -118.4749   True
# Entire home/apt  Shared room -152.5351  0.001 -179.6239 -125.4464   True
#    Private room  Shared room  -25.7879 0.0168  -53.1857    1.6098  False
# ------------------------------------------------------------------------

# %% [markdown]
# The TukeyHSD post hoc test reveals that the price for “entire home/apt” is statistically significantly higher than for private (p < 0.001) and shared room (p < 0.001).<br>
# There is no statistically significant difference between the shared and private room (p = 0.0168).

# %% [markdown]
# ## Conclusion:
# Manhattan has significantly higher prices than the rest of NYC. Renting an entire home/apartment in Manhattan is significantly more expensive than renting a private room or shared room. <br>
# However, there is no significant difference in the price for the shared or private room.
